# %% [markdown]
# <a href="https://colab.research.google.com/github/Kuldharnilakshi/Python/blob/main/Data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('/content/titanic-training-data.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df=df.drop(["PassengerId","Name","Ticket","cabin"],axis=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-6aaa41a29270> in <cell line: 1>()
# ----> 1 df=df.drop(["PassengerId","Name","Ticket","cabin"],axis=1)
#       2 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
#Univariate
## for cataborical attribute

# %%
sns.countplot(x="Survived",data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x="Sex",data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x="Embarked",data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x="Pclass",data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## for numerical attribute

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
sns.boxplot(x="Age",data=df)
plt.show()

# %%
sns.boxplot(x="SibSp",data=df)
plt.show()

# %%
sns.boxplot(x="Fare",data=df)
plt.show()

# %%
sns.boxplot(x="Parch",data=df)
plt.show()

# %%
sns.boxplot(x="SibSp",data=df)
plt.show()

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
plt.hist("Age",data=df)
plt.show()

# %%
## Bivariate

# %%
sns.countplot(x="Survived",hue="Sex",data=df)
plt.show()

# %%
sns.countplot(x="Survived",hue="Pclass",data=df)
plt.show()

# %%
sns.countplot(x="Survived",hue="Embarked",data=df)
plt.show()

# %%
sns.relplot(x="Parch",y="Fare",data=df)

# %%
sns.relplot(x="Age",y="Fare",data=df)

# %%
sns.relplot(x="SibSp",y="Fare",data=df)

# %%
sns.relplot(x="Fare",y="Parch",data=df)

# %%
sns.relplot(x="Parch",y="Pclass",data=df)

# %%
sns.catplot(x="Survived",y="Age",data=df)

# %%
sns.catplot(x="Pclass",y="Age",data=df)

# %%
sns.catplot(x="Survived",y="Age",data=df,kind="box")

# %%
sns.catplot(x="Pclass",y="Age",data=df,kind="box")

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
sns.catplot(x="Pclass",y="Age",data=df,kind="swarm")

# %%
sns.catplot(x="Pclass",y="Age",data=df,kind="violin")

# %%
sns.pairplot(df)

# %%
### Multivariate analysis

# %%
sns.catplot(x="Survived",y="Age",hue="Sex",data=df)

# %%
sns.catplot(x="Pclass",y="Age",hue="Sex",data=df)

# %%
sns.catplot(x="SibSp",y="Age",hue="Sex",data=df)

# %%
sns.catplot(x="Survived",y="Age",hue="Pclass",data=df)

# %%
sns.catplot(x="Survived",y="Age",hue="Pclass",data=df ,kind="violin")
